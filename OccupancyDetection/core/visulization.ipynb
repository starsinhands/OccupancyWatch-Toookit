# %%
import numpy as np
import pandas as pd
from sklearn.metrics import f1_score, accuracy_score
from utility import calculate_f1, majority_vote_filter
from matplotlib import pyplot as plt
import pandas as pd
path = r"C:\Users\ASUS\Desktop\OccupancyWatch\result\ECO\b1"
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
winter_cross_prediction = np.load(r"C:\Users\ASUS\Desktop\OccupancyWatch\result\ECO\b1\lstm\winter\cross_prediction.npy").reshape(-1)
winter_cross_ground_truth = np.load(r"C:\Users\ASUS\Desktop\OccupancyWatch\result\ECO\b1\lstm\winter\cross_ground_truth.npy").reshape(-1)

# %%
winter_same_prediction = np.load(r"C:\Users\ASUS\Desktop\OccupancyWatch\result\ECO\b1\lstm\winter\same_winter_prediction.npy").reshape(-1)
winter_same_ground_truth = np.load(r"C:\Users\ASUS\Desktop\OccupancyWatch\result\ECO\b1\lstm\winter\same_winter_ground_truth.npy").reshape(-1)

# %%
summer_cross_prediction = np.load(r"C:\Users\ASUS\Desktop\OccupancyWatch\result\ECO\b1\lstm\summer\cross_prediction.npy").reshape(-1)
summer_cross_ground_truth = np.load(r"C:\Users\ASUS\Desktop\OccupancyWatch\result\ECO\b1\lstm\summer\cross_ground_truth.npy").reshape(-1)

# %%
summer_same_prediction = np.load(r"C:\Users\ASUS\Desktop\OccupancyWatch\result\ECO\b1\lstm\summer\same_prediction.npy").reshape(-1)
summer_same_ground_truth = np.load(r"C:\Users\ASUS\Desktop\OccupancyWatch\result\ECO\b1\lstm\summer\same_ground_truth.npy").reshape(-1)

# %%
winter_same_ground_truth
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
plt.figure(figsize=(15,8))
# plot the summer occcupancy

plt.subplot(3,2,1)
plt.yticks([0,1])
plt.ylabel("Ground Truth")
plt.title("Summer")
plt.plot(summer_same_ground_truth)

plt.subplot(3,2,3)
plt.yticks([0,1])
plt.plot(summer_same_prediction)
plt.ylabel("Test on ame Dataset")

plt.subplot(3,2,5)
plt.yticks([0,1])
plt.plot(winter_cross_prediction[-11208:])
plt.ylabel("Test on Cross Dataset")

# plot the winter occcupancy
plt.subplot(3,2,2)
plt.title("Winter")
plt.yticks([0,1])
plt.plot(winter_same_ground_truth)

plt.subplot(3,2,4)
plt.yticks([0,1])
plt.plot(winter_same_prediction)

plt.subplot(3,2,6)
plt.yticks([0,1])
plt.plot(summer_cross_prediction[-13238:])
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# winter_same_ground_truth
plt.figure(figsize=(15, 8))
# plot the summer occcupancy

plt.subplot(3, 2, 1)
plt.yticks([0, 1])
plt.ylabel("Ground Truth",size=12)
plt.title("Summer",size=15)
plt.plot(summer_same_ground_truth)

plt.subplot(3, 2, 3)
plt.yticks([0, 1])
plt.plot(summer_same_prediction)
plt.ylabel("Test on Same Dataset",size=12)

plt.subplot(3, 2, 5)
plt.yticks([0, 1])
plt.plot(winter_cross_prediction[-11208:])
plt.ylabel("Test on Cross Dataset",size=12)

# plot the winter occcupancy
plt.subplot(3, 2, 2)
plt.title("Winter",size=15)
plt.yticks([0, 1])
plt.plot(winter_same_ground_truth)

plt.subplot(3, 2, 4)
plt.yticks([0, 1])
plt.plot(winter_same_prediction)

plt.subplot(3, 2, 6)
plt.yticks([0, 1])
plt.plot(summer_cross_prediction[-13238:])
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# Create a figure and axis
plt.figure(figsize=(15, 8))
# Summer Occupancy
plt.subplot(3, 2, 1)
plt.yticks([0, 1])
# plt.ylabel("Ground Truth",size=15)
plt.title("Summer Occupancy",size=15)
plt.ylabel("Ground Truth",size=15)

plt.plot(summer_same_ground_truth, label="Ground Truth", color="blue", linestyle="-")

plt.subplot(3, 2, 3)
plt.yticks([0, 1])
plt.plot(summer_same_prediction, label="Test on Same Dataset", color="green", linestyle="-")
# plt.ylabel("Predictions",size=15)
plt.ylabel("Test on Same Dataset",size=15)

plt.subplot(3, 2, 5)
plt.yticks([0, 1])
plt.ylabel("Test on Cross Dataset",size=15)
plt.plot(summer_cross_prediction, label="Test on Cross Dataset", color="red", linestyle="-")
# plt.ylabel("Same Training Set Predictions",size=15)

# Winter Occupancy
plt.subplot(3, 2, 2)
plt.title("Winter Occupancy",size=15)
plt.yticks([0, 1])
plt.plot(winter_same_ground_truth, label="Ground Truth", color="blue", linestyle="-")
# plt.legend(loc="upper right")

plt.subplot(3, 2, 4)
plt.yticks([0, 1])
plt.plot(winter_same_prediction, label="Test on Same Dataset", color="green", linestyle="-")
# plt.legend(loc="upper right")

plt.subplot(3, 2, 6)
plt.yticks([0, 1])
plt.plot(winter_cross_prediction, label="Test on Cross Dataset", color="red", linestyle="-")
# plt.legend(loc="upper right")

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
plt.plot(winter_cross_prediction)

# %%
import matplotlib.pyplot as plt
import numpy as np

# 假设的F1 macro分数数据
summer_data = {
    'HMM_same': 0.85,
    'LSTM_same': 0.90,
    'HMM_cross': 0.75,
    'LSTM_cross': 0.80
}

winter_data = {
    'HMM_same': 0.70,
    'LSTM_same': 0.75,
    'HMM_cross': 0.65,
    'LSTM_cross': 0.70
}

import matplotlib
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(13, 4))
# 构造x轴刻度标签、数据
labels = ['G1', 'G2', 'G3', 'G4']
first = [20, 34, 30, 35]
second = [25, 32, 34, 20]
third = [21, 31, 37, 21]
fourth = [26, 31, 35, 27]

x = np.arange(len(labels))  # x轴刻度标签位置
width = 0.25  # 柱子的宽度
# 计算每个柱子在x轴上的位置，保证x轴刻度标签居中
# x - width/2，x + width/2即每组数据在x轴上的位置
plt.bar(x - width/2, first, width, label='1')
plt.bar(x + width/2, second, width, label='2')
plt.ylabel('F1-macro Scores')
# x轴刻度标签位置不进行计算
plt.xticks(x, labels=labels)
plt.legend()

plt.show()
